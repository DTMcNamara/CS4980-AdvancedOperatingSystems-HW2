# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
index = list(np.arange(1,49))
values = [66,	5,	4,	4,	5,	6,	3,	10,	4,	4,	3,	3,	2,	7,	2,	2,	4,	2,	1,	1, 2,	2,	2,	4,	3,	3,	2,	1,	2,	4,	4,	3,	3,	2,	3,	4,	3,	2,	3,	2,	2,	4,	2,2,	2,	3,	2,	2]
plt.plot(index,values)
plt.savefig('mc.png')
plt.show()

# %%
index = list(np.arange(1,50))
values = [15,9,4,2,2,3,2,3,9,4,2,4,5,3,3,4,9,79,4,3,2,6,4,4,9,2,3,3,2,2,4,3,2,3,3,8,5,12,3,3,17,9,5,2,8,4,4,14,7]
plt.plot(index,values)
plt.savefig('mca.png')
plt.show()

# %%
index = list(np.arange(1,50))
values = [33,5,11,9,11,9,13,16,16,26,19,19,23,22,23,26,24,28,30,31,34,31,38,34,35,39,41,44,41,42,44,53,47,48,49,52,53,57,53,58,59,59,59,62,59,62,65,66,66]
plt.plot(index,values)
plt.savefig('pac.png')
plt.show()
